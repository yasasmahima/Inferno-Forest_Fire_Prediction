# %%
# Fosberg Fire Weather Index Equation Implementation

import numpy as np

def equilibriumMositureContent(realtiveHumidity,temperature):
    if (realtiveHumidity<=10.0):
        equilibriumMositureContent=0.03229 + 0.281073*realtiveHumidity - 0.000578*realtiveHumidity*temperature

    elif(10.0<realtiveHumidity<=50.0):
        equilibriumMositureContent=2.22749 + 0.160107*realtiveHumidity - 0.01478*temperature;

    elif(realtiveHumidity>50.0):
        equilibriumMositureContent=21.0606 + 0.005565*realtiveHumidity*realtiveHumidity - 0.00035*realtiveHumidity*temperature - 0.483199*realtiveHumidity

    # print(equilibriumMositureContent)

    return equilibriumMositureContent;


def moistureDampingCoefficient(equilibriumMositureContent):

    equilibriumMositureContent30=equilibriumMositureContent/30

    moistureDampingCoefficient=1-(2*equilibriumMositureContent30)+1.5*(equilibriumMositureContent30*equilibriumMositureContent30)-0.5*(equilibriumMositureContent30*equilibriumMositureContent30*equilibriumMositureContent30)
    # print(moistureDampingCoefficient)
    return moistureDampingCoefficient


def FWI(moistureDampingCoefficient,windSpeed):

    powWindSpeed=windSpeed*windSpeed;

    fwi=(moistureDampingCoefficient*np.sqrt(1+powWindSpeed))/0.3002
    # fwi=moistureDampingCoefficient*[(1+windSpeed^2)^0.5]/0.3002
    return fwi;

f1 = open("windSpeed.txt", "r")
line1=f1.readlines()
f2 = open("temperatures.txt", "r")
line2=f2.readlines()
f3 = open("Relativehumidity.txt", "r")
line3=f3.readlines()
f4 = open("dates.txt", "r")
line4=f4.readlines()
f5 = open("spread.txt", "r")
line5=f5.readlines()

for i in range(180):
    relativeHumidity=float(line3[i])
    temperature=float(line2[i])
    windSpeed=float(line1[i])
    
    
    
    e=equilibriumMositureContent(relativeHumidity,temperature)
    m=moistureDampingCoefficient(e)
    fwi=FWI(m,windSpeed)
    
    print("Fosberg Fire Weather Index Rating Scale",fwi%100)
    
    print("Date : ",line4[i])

    ratingSacle=fwi%100

    if(ratingSacle<5.2):
        print("Very Low Risk")

    elif(5.2<=ratingSacle<11.2):
        print("Low Risk")

    elif(11.2<=ratingSacle<21.3):
        print("Moderate Risk")

    elif(21.3<=ratingSacle<38.0):
        print("High Risk")

    elif(38.0<=ratingSacle<50.0):
        print("Very High Risk")

    else:
        print("Extreme")
        
    
    if(ratingSacle>=11.2):
            print("Number of Area can be Burn: ",line5[i])
        
    
    print("\n\n")
    


    
    
    

# relativeHumidity=float(input("Input Humidity : "))
# temperature=float(input('Input Temperature in Fahrenheits : '))
# windSpeed=float(input("Input Wind speed in MPH: "))

# e=equilibriumMositureContent(relativeHumidity,temperature)
# m=moistureDampingCoefficient(e)

# fwi=FWI(m,windSpeed)

# print("FOsberg Fire Weather Index Rating Scale",fwi%100)

# ratingSacle=fwi%100

# if(ratingSacle<5.2):
#     print("Very Low Risk")

# elif(5.2<=ratingSacle<11.2):
#     print("Low Risk")

# elif(11.2<=ratingSacle<21.3):
#     print("Moderate Risk")

# elif(21.3<=ratingSacle<38.0):
#     print("High Risk")

# elif(38.0<=ratingSacle<50.0):
#     print("Very High Risk")

# else:
#     print("Extreme")
# Out:
# Fosberg Fire Weather Index Rating Scale 11.02897727167504
# Date :  2019-08-06T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.453523638466768
# Date :  2019-08-07T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.408200000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.41275714951601
# Date :  2019-08-08T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.594450000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 28.163560616077554
# Date :  2019-08-09T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  16.464849999999988
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 21.5657903762034
# Date :  2019-08-10T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  14.824349999999999
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 26.514721632568055
# Date :  2019-08-11T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  5.542100000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 23.789895506693163
# Date :  2019-08-12T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  6.126150000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.814625073856963
# Date :  2019-08-13T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  6.256300000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.788105410100851
# Date :  2019-08-14T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.716400000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.400015569764324
# Date :  2019-08-15T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.280600000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.099543655251384
# Date :  2019-08-16T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  6.081700000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.218854301994009
# Date :  2019-08-17T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  5.563400000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.98561429073029
# Date :  2019-08-18T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  13.009499999999985
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.17441609191806
# Date :  2019-08-19T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.156949999999986
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.4626992833917
# Date :  2019-08-20T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.603399999999997
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.15929350094546
# Date :  2019-08-21T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.137899999999995
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 21.36806391123339
# Date :  2019-08-22T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  12.619699999999993
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.059179563710355
# Date :  2019-08-23T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  5.955500000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.289454207767564
# Date :  2019-08-24T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  6.475500000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.213332399759148
# Date :  2019-08-25T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  6.768100000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.493021594070221
# Date :  2019-08-26T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  13.978749999999986
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.551023855959842
# Date :  2019-08-27T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  16.06025
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.009717882572994
# Date :  2019-08-28T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.833399999999994
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.989575632201456
# Date :  2019-08-29T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.1068
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.818687102420892
# Date :  2019-08-30T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.081250000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.766108704439134
# Date :  2019-08-31T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.742977965417309
# Date :  2019-09-01T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.636500000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.594891361022706
# Date :  2019-09-02T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.940680704181808
# Date :  2019-09-03T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  24.32170000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.309439869868472
# Date :  2019-09-04T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  21.0746
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.994648989801737
# Date :  2019-09-05T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  30.04235000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.485306605371504
# Date :  2019-09-06T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  27.265600000000013
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 31.1083739205971
# Date :  2019-09-07T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  19.84950000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 20.814312611699766
# Date :  2019-09-08T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  22.937850000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 27.618602352051955
# Date :  2019-09-09T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  26.24545000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.299018799094952
# Date :  2019-09-10T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  15.448899999999991
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.56134711902763
# Date :  2019-09-11T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.582900000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.17602135506454
# Date :  2019-09-12T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.777122319014666
# Date :  2019-09-13T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  28.22540000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.52020371317545
# Date :  2019-09-14T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  13.859449999999988
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.779497329887844
# Date :  2019-09-15T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  18.050099999999997
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.174892742461187
# Date :  2019-09-16T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  24.25525000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.68779232622276
# Date :  2019-09-17T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  34.49990000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.204344785226285
# Date :  2019-09-18T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  16.6035
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.821171076650286
# Date :  2019-09-19T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  19.690600000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.112875686678075
# Date :  2019-09-20T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.632400000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.332935322846907
# Date :  2019-09-21T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.41375000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.240009319691628
# Date :  2019-09-22T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.580600000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.208171903975586
# Date :  2019-09-23T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.053766666666675
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.114452725600167
# Date :  2019-09-24T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  28.557200000000016
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.55791556455083
# Date :  2019-09-25T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.050386187292899
# Date :  2019-09-26T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  16.08355
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.457011428187668
# Date :  2019-09-27T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.603250763847932
# Date :  2019-09-28T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  10.185700000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.32488533913236
# Date :  2019-09-29T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.168100000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.097619379947997
# Date :  2019-09-30T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  19.915500000000016
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.045779197836094
# Date :  2019-10-01T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.983400000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.378109216730177
# Date :  2019-10-02T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.576650000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.6684267262474
# Date :  2019-10-03T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.035099999999996
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.487953670863856
# Date :  2019-10-04T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.278500000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.705535594599887
# Date :  2019-10-05T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.031500000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.763096187783725
# Date :  2019-10-06T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.221500000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.244009442113244
# Date :  2019-10-07T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.201900000000009
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.400802341302935
# Date :  2019-10-08T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.436600000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 21.671866470004293
# Date :  2019-10-09T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  9.715400000000011
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.12906341826705
# Date :  2019-10-10T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  10.712399999999995
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.374478351850449
# Date :  2019-10-11T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.72205000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.852171555047708
# Date :  2019-10-12T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.142850000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.848972634189565
# Date :  2019-10-13T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.389075540318053
# Date :  2019-10-14T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.118733333333338
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.465196249080213
# Date :  2019-10-15T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.975300000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.305245428659314
# Date :  2019-10-16T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.882993487960416
# Date :  2019-10-17T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  29.811500000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.22738152803819
# Date :  2019-10-18T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.626900000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.880080073917092
# Date :  2019-10-19T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  10.503199999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.82059346800183
# Date :  2019-10-20T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.455700000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.981155577759136
# Date :  2019-10-21T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.808700000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.017601090222152
# Date :  2019-10-22T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.984300000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.715460238689703
# Date :  2019-10-23T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.057500000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.93497491203211
# Date :  2019-10-24T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.227900000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.729616024475563
# Date :  2019-10-25T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.31038333333334
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.17807583197396
# Date :  2019-10-26T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.24460000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.006045362736323
# Date :  2019-10-27T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.164950000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.732519625964139
# Date :  2019-10-28T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  5.5928
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.366425720656714
# Date :  2019-10-29T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.053100000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.75343899955747
# Date :  2019-10-30T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.633700000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.787992041868364
# Date :  2019-10-31T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.865300000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.464060369196867
# Date :  2019-11-01T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.812600000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.545377450215028
# Date :  2019-11-02T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.06858333333334
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.065649619502143
# Date :  2019-11-03T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.051633333333337
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.840716336321197
# Date :  2019-11-04T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  18.266099999999987
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.8757687669554
# Date :  2019-11-05T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.871883333333335
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.791061343110975
# Date :  2019-11-06T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  26.874700000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.129786786203795
# Date :  2019-11-07T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  20.835550000000012
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 23.604774300748105
# Date :  2019-11-08T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  15.338350000000009
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 29.053757036589676
# Date :  2019-11-09T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  12.539800000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.789581691754996
# Date :  2019-11-10T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  34.35420000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.481973338459287
# Date :  2019-11-11T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.300900000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.039540094697259
# Date :  2019-11-12T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.632500000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 21.804148136158723
# Date :  2019-11-13T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  12.316600000000015
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.557084559676355
# Date :  2019-11-14T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.578900000000008
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.729543991529248
# Date :  2019-11-15T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.068900000000012
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.289396144602474
# Date :  2019-11-16T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  16.835300000000014
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.078108872430622
# Date :  2019-11-17T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.470950000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 19.933764232936483
# Date :  2019-11-18T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  12.136949999999999
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.810435296857815
# Date :  2019-11-19T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.6769500000000015
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.66732186203165
# Date :  2019-11-20T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.998750000000003
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.919876337319439
# Date :  2019-11-21T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  21.6776
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.022974802278167
# Date :  2019-11-22T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  2.278800000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.521281480923932
# Date :  2019-11-23T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.1976
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.166380727803077
# Date :  2019-11-24T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  37.7356
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 12.08086829361848
# Date :  2019-11-25T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  6.359883333333336
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.550848551458415
# Date :  2019-11-26T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  7.408683333333337
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.954645876686156
# Date :  2019-11-27T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  29.87626666666667
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.342957669474295
# Date :  2019-11-28T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  32.06639999999997
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.36102252746189
# Date :  2019-11-29T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  46.155499999999975
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.530279621823933
# Date :  2019-11-30T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  29.17549999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.665330248904699
# Date :  2019-12-01T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  1.8654999999999986
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.017681149761726
# Date :  2019-12-02T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  1.0561
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 24.396776566581533
# Date :  2019-12-03T00:00:00.000000000
#
# High Risk
# Number of Area can be Burn:  9.034583333333341
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.959137792888644
# Date :  2019-12-04T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  41.141549999999995
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.113847822230348
# Date :  2019-12-05T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  34.05195000000002
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.1693100381509
# Date :  2019-12-06T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.042600000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.576987609240273
# Date :  2019-12-07T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  17.146550000000012
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.910627298076662
# Date :  2019-12-08T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.607550000000005
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.853697450605477
# Date :  2019-12-09T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  21.989199999999993
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.880670590619435
# Date :  2019-12-10T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  38.85519999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.78334928526905
# Date :  2019-12-11T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  2.5220000000000016
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.981845919547425
# Date :  2019-12-12T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  11.314199999999996
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.943968994483097
# Date :  2019-12-13T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  30.010499999999993
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.070533209191385
# Date :  2019-12-14T00:00:00.000000000
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.826570745280069
# Date :  2019-12-15T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  35.46049999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.50748100779875
# Date :  2019-12-16T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.5745999999999993
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.060567868398643
# Date :  2019-12-17T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  20.231399999999947
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.933732378398258
# Date :  2019-12-18T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  22.746599999999994
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.92985458111787
# Date :  2019-12-19T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.5850000000000057
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.02595554997829
# Date :  2019-12-20T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.2401000000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 13.989037024623865
# Date :  2019-12-21T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  9.416900000000004
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.372706533524727
# Date :  2019-12-22T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  4.5987
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.486035468424555
# Date :  2019-12-23T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  30.006966666666667
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 14.2436293904653
# Date :  2019-12-24T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  27.903049999999993
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.942986408553425
# Date :  2019-12-25T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.5732000000000035
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.02048314882051
# Date :  2019-12-26T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  26.300999999999995
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 18.365884799852594
# Date :  2019-12-27T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  8.074466666666671
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 17.905541553928316
# Date :  2019-12-28T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.799499999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.392481848782005
# Date :  2019-12-29T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  13.048300000000001
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 16.880450368906985
# Date :  2019-12-30T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.767199999999987
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.383070601152243
# Date :  2019-12-31T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  5.504200000000006
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 15.537499785207979
# Date :  2020-01-01T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  3.2375000000000007
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.422262281472715
# Date :  2020-01-02T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.243858158254993
# Date :  2020-01-03T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  14.322399999999998
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.859545881895349
# Date :  2020-01-04T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 11.34847979444479
# Date :  2020-01-05T00:00:00.000000000
#
# Moderate Risk
# Number of Area can be Burn:  30.503699999999995
#
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.066052462535303
# Date :  2020-01-06T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.654745717261232
# Date :  2020-01-07T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.090002797304916
# Date :  2020-01-08T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.098575448564699
# Date :  2020-01-09T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.245819059515103
# Date :  2020-01-10T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.536503149221495
# Date :  2020-01-11T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.023722640637152
# Date :  2020-01-12T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.970010969053492
# Date :  2020-01-13T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.336456948685518
# Date :  2020-01-14T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 7.4549242610048605
# Date :  2020-01-15T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 7.451723836454111
# Date :  2020-01-16T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.435806136195458
# Date :  2020-01-17T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 6.4075019424330835
# Date :  2020-01-18T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 6.208354474661117
# Date :  2020-01-19T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 7.373950885873051
# Date :  2020-01-20T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.830174752380742
# Date :  2020-01-21T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 10.241840612636384
# Date :  2020-01-22T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.03308263225445
# Date :  2020-01-23T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.308370335870851
# Date :  2020-01-24T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.915437590738671
# Date :  2020-01-25T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 6.5048818620826845
# Date :  2020-01-26T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 9.187266932550676
# Date :  2020-01-27T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.136633599362392
# Date :  2020-01-28T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.66996868129253
# Date :  2020-01-29T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.094741044836196
# Date :  2020-01-30T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.072502873152427
# Date :  2020-01-31T00:00:00.000000000
#
# Low Risk
#
#
#
# Fosberg Fire Weather Index Rating Scale 8.761883529083777
# Date :  2020-02-01T00:00:00.000000000
#
# Low Risk
